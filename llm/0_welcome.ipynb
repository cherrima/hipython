# %% [markdown]
# # 환경변수 로드하기

# %%
from dotenv import load_dotenv
import os

load_dotenv(r"D:\Practice\hipython\llm\.env", override=True)

OPENAI_API_KEY = os.environ['OPENAI_API_KEY']
#PINECONE_API_KEY = os.environ['PINECONE_API_KEY']

print("API 키 로드 완료")
print(f"OpenAI Key: {OPENAI_API_KEY[:10]}...")
# Out:
# API 키 로드 완료
# OpenAI Key: sk-proj-00...

# %% [markdown]
# # LangChain 버전 확인

# %%
import langchain
print(langchain.__version__)
# Out:
# 1.2.15

# %% [markdown]
# # LCEL 기본 체인 동작 확인

# %%
# Step 2 : LCEL 기본 체인 동작 확인
# from dotenv import load_dotenv
# load_dotenv()

from langchain_openai import ChatOpenAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser

llm = ChatOpenAI(model="gpt-4o-mini")
prompt = PromptTemplate.from_template("{topic}에 대해 한 문장으로 설명해줘")
prompt_2 = PromptTemplate.from_template("{topic}에 대해 {count}개 문장으로 설명해줘")
chain = prompt | llm | StrOutputParser()
chain_2 = prompt_2 | llm | StrOutputParser()

result = chain.invoke({"topic": "RAG"})
print(result)

result_2 = chain_2.invoke({"topic": "LangChain", "count" : 2})
print(result_2)
# Out:
# RAG( Retrieval-Augmented Generation)는 정보 검색과 생성 모델을 결합하여, 외부 지식에 기반한 더 정확하고 풍부한 응답을 생성하는 기술입니다.
# LangChain은 다양한 언어 모델과 AI 시스템을 통합하여 자연어 처리 애플리케이션을 구축할 수 있도록 돕는 프레임워크입니다. 이 프레임워크는 데이터 소스, API, 대화형 인터페이스를 손쉽게 연결하여 복잡한 NLP 파이프라인을 구성할 수 있는 기능을 제공합니다.

# %%
llm = ChatOpenAI(model="gpt-4o-mini")

messages = [
    ("system", "당신은 서울의 음식과 문화 전문가입니다."),
    ("human", "서울을 대표하는 음식을 맛볼 수 있는 레스토랑 5개를 추천해 주세요. 위치도 같이 알려주세요") 
]

response = llm.invoke(messages)
print(response.content)
# Out:
# 서울에서 대표적인 음식을 맛볼 수 있는 레스토랑 5곳을 추천해 드리겠습니다. 각 레스토랑의 위치도 함께 안내해 드릴게요.
#
# 1. **갓포 다다 (Kappo Dada)**
#    - **음식**: 전통 한식
#    - **위치**: 서울특별시 강남구 도산대로30길 18
#    - **설명**: 계절별 재료를 사용한 정통 한정식과 각종 전통 한식을 제공합니다. 아늑한 분위기에서 식사를 즐길 수 있습니다.
#
# 2. **부대찌개 1943 (Budaejjigae 1943)**
#    - **음식**: 부대찌개
#    - **위치**: 서울특별시 용산구 한남동 736-22
#    - **설명**: 부대찌개의 발상지로 유명하며, 풍부한 육수와 다양한 재료가 조화를 이루는 맛을 제공합니다.
#
# 3. **광장시장 (Gwangjang Market)**
#    - **음식**: 전통 먹거리 (빈대떡, 육회 등)
#    - **위치**: 서울특별시 종로구 창경궁로 88
#    - **설명**: 서울의 대표적인 재래시장으로, 다양한 한국 전통 음식을 즉석에서 즐길 수 있는 곳입니다. 빈대떡과 육회가 특히 유명합니다.
#
# 4. **이탤리안 레스토랑 피오레 (Ristorante Fiore)**
#    - **음식**: 이탈리안식 김치 파스타
#    - **위치**: 서울특별시 종로구 북촌로 26
#    - **설명**: 한국 재료를 활용한 퓨전 이탈리아 요리를 제공하며, 특별히 김치 파스타가 인기입니다. 독특한 맛을 경험할 수 있습니다.
#
# 5. **정식당 (Jungsik)**
#    - **음식**: 현대적인 한식
#    - **위치**: 서울특별시 강남구 압구정로 46길 8
#    - **설명**: 미슐랭 스타를 받은 레스토랑으로, 현대적인 해석을 가미한 한식을 제공합니다. 세련된 분위기와 함께 색다른 한식을 즐길 수 있습니다.
#
# 이 레스토랑들은 서울의 다양한 맛을 경험할 수 있는 좋은 장소들입니다. 예약을 권장합니다!
