# %%
import ultralytics

ultralytics.checks()# 버전 사용환경
# Out:
# Ultralytics 8.4.31  Python-3.11.15 torch-2.6.0+cu124 CUDA:0 (NVIDIA GeForce RTX 4060 Laptop GPU, 8188MiB)
# Setup complete  (16 CPUs, 31.7 GB RAM, 2.4/200.0 GB disk)

# %%
from PIL import Image # Pillow
from IPython.display import display

output_file = "street2.jpg"

with Image.open(output_file) as test_image:
    display(test_image)

# %%
from ultralytics import YOLO

# MS COCO 데이터셋 사전학습된 yolov8 모델 로드함
model = YOLO('yolov8n.pt')

# %%
print(type(model.names), len(model.names))
print(model.names)

# %%
results = model.predict(source='*.jpg', save=True)

# %%
from PIL import Image
from IPython.display import display

with Image.open('runs/detect/predict/'+output_file) as pred_image:
    # 이미지를 display 함수를 사용하여 표시합니다.
    display(pred_image)

# %%
import numpy as np

for result in results:

    uniq, cnt = np.unique(result.boxes.cls.cpu().numpy(), return_counts=True)  # Torch.Tensor -> numpy
    uniq_cnt_dict = dict(zip(uniq, cnt))

    print('\n{class num:counts} =', uniq_cnt_dict,'\n')

    for c in result.boxes.cls:
        print('class num =', int(c), ', class_name =', model.names[int(c)])

# %%
from ultralytics import YOLO

model = YOLO('yolov8n-seg.pt')
print(type(model.names), len(model.names))
print(model.names)

# %%
from PIL import Image
from IPython.display import display

# 이미지 파일을 열고
with Image.open('desktop.jpg') as test_image1:
    # 이미지를 display 함수를 사용하여 표시합니다.
    display(test_image1)

# %%
results = model.predict(source='desktop.jpg', save=True)

# %%
import cv2
import matplotlib.pyplot as plt

result_img = cv2.imread("runs/segment/predict/desktop.jpg")

plt.figure(figsize=(12, 8))
plt.imshow(cv2.cvtColor(result_img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()
